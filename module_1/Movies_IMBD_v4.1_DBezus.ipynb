# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
imdb = pd.read_csv('movie_bd_v5.csv')
imdb['profit'] = imdb.revenue - imdb.budget
imdb.sample(5)
# Out:
#         imdb_id    budget   revenue       original_title  \
# 1338  tt0378109  50000000  44434439        Into the Blue
# 936   tt0253556  60000000  43061982        Reign of Fire
# 1737  tt0425413  10000000  33000000       Run Fatboy Run
# 273   tt1121931  20000000  34560577  Crank: High Voltage
# 350   tt1078588  30000000  95714875   My Sister's Keeper
#
#                                                    cast  \
# 1338  Paul Walker|Jessica Alba|Scott Caan|Ashley Sco...
# 936   Christian Bale|Matthew McConaughey|Izabella Sc...
# 1737  Simon Pegg|Thandie Newton|Hank Azaria|Dylan Mo...
# 273   Jason Statham|Amy Smart|Dwight Yoakam|Efren Ra...
# 350   Cameron Diaz|Alec Baldwin|Abigail Breslin|Joan...
#
#                          director  \
# 1338               John Stockwell
# 936                    Rob Bowman
# 1737              David Schwimmer
# 273   Mark Neveldine|Brian Taylor
# 350               Nick Cassavetes
#
#                                                 tagline  \
# ...

# %%
imdb.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# тут другие ваши предобработки колонок например:

#the time given in the dataset is in string format.
#So we need to change this in datetime format
# ...

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# в словарь вставляем номер вопроса и ваш ответ на него
# Пример: 
answers['1'] = '2. Spider-Man 3 (tt0413300)'
# запишите свой вариант ответа
answers['1'] = 'Pirates of the Caribbean: On Stranger Tides (tt1298650)'
# если ответили верно, можете добавить комментарий со значком "+"

# %%
# тут пишем ваш код для решения данного вопроса:
imdb=pd.read_csv(r'movie_bd_v5.csv')
imdb[imdb.budget==imdb.budget.max()]
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  \
# 723  Adventure|Action|Fantasy
#
#                                   production_companies release_date  \
# 723  Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
#
#      vote_average  release_year
# 723           6.3          2011

# %% [markdown]
# ВАРИАНТ 2

# %%
# можно добавлять разные варианты решения

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
# думаю логику работы с этим словарем вы уже поняли, 
# по этому не буду больше его дублировать
answers['2'] = 'Gods and Generals (tt0279111)'
# +

# %%
imdb[imdb.runtime==imdb.runtime.max()]
# Out:
#         imdb_id    budget   revenue     original_title  \
# 1157  tt0279111  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1157  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1157  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1157  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1157  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_average  release_year
# 1157           5.8          2003

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
answers['3'] = 'Winnie the Pooh (tt1449283)'
# +

# %%
imdb[imdb.runtime==imdb.runtime.min()]
# Out:
#        imdb_id    budget   revenue   original_title  \
# 768  tt1449283  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 768  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 768  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 768  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 768  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_average  release_year
# 768    4/13/2011           6.8          2011

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
answers['4'] = '110'
# +

# %%
imdb.runtime.mean()
# Out:
# 109.6585494970884

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
answers['5'] = '107'
# +

# %%
imdb.runtime.median()
# Out:
# 107.0

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
answers['6'] = 'Avatar (tt0499549)'
# +

# %%
# лучше код получения столбца profit вынести в Предобработку что в начале
# Вариант 1 
imdb[imdb.profit==imdb.profit.max()]
# Out:
#        imdb_id     budget     revenue original_title  \
# 239  tt0499549  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_average  release_year      profit
# 239           7.1          2009  2544505847

# %%
# Вариант 2 
imdb.sort_values(['profit'],ascending=False)
# Out:
#         imdb_id     budget     revenue                original_title  \
# 239   tt0499549  237000000  2781505847                        Avatar
# 3     tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 0     tt0369610  150000000  1513528810                Jurassic World
# 4     tt2820852  190000000  1506249360                     Furious 7
# 970   tt0848228  220000000  1519557910                  The Avengers
# ...         ...        ...         ...                           ...
# 1464  tt0424095  149000000    64459316                  Flushed Away
# 958   tt0180052  100000000     7103973  The Adventures of Pluto Nash
# 809   tt1305591  150000000    38992758               Mars Needs Moms
# 1616  tt0318974  145000000    25819961                     The Alamo
# 1245  tt1210819  255000000    89289910               The Lone Ranger
#
#                                                    cast  \
# 239   Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# ...

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
answers['7'] = 'The Lone Ranger (tt1210819)'
# +

# %%
# Вариант 1 
imdb.sort_values(['profit'])
# Out:
#         imdb_id     budget     revenue                original_title  \
# 1245  tt1210819  255000000    89289910               The Lone Ranger
# 1616  tt0318974  145000000    25819961                     The Alamo
# 809   tt1305591  150000000    38992758               Mars Needs Moms
# 958   tt0180052  100000000     7103973  The Adventures of Pluto Nash
# 1464  tt0424095  149000000    64459316                  Flushed Away
# ...         ...        ...         ...                           ...
# 970   tt0848228  220000000  1519557910                  The Avengers
# 4     tt2820852  190000000  1506249360                     Furious 7
# 0     tt0369610  150000000  1513528810                Jurassic World
# 3     tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 239   tt0499549  237000000  2781505847                        Avatar
#
#                                                    cast  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...
# ...

# %%
# Вариант 2 
imdb[imdb.profit==imdb.profit.min()]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit
# 1245           6.0          2013 -165710090

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
answers['8'] = '1478'
# +

# %%
imdb[imdb.profit>0].count()
# Out:
# imdb_id                 1478
# budget                  1478
# revenue                 1478
# original_title          1478
# cast                    1478
# director                1478
# tagline                 1478
# overview                1478
# runtime                 1478
# genres                  1478
# production_companies    1478
# release_date            1478
# vote_average            1478
# release_year            1478
# profit                  1478
# dtype: int64

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
answers['9'] = 'The Dark Knight (tt0468569)'
# +

# %%
# Вариант 1 
p=imdb[imdb.release_year==2008].profit.max()
display(p)
imdb[imdb.profit==816921825]
# Out:
# 816921825
#        imdb_id     budget     revenue   original_title  \
# 599  tt0468569  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 599  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 599      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 599  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_average  release_year     profit
# 599           8.1          2008  816921825

# %%
# Вариант 2 
imdb_2008=imdb[imdb.release_year==2008]
imdb_2008.sort_values(['profit'],ascending=False)
# Out:
#        imdb_id     budget     revenue  \
# 599  tt0468569  185000000  1001921825
# 603  tt0367882  185000000   786636033
# 607  tt0795421   52000000   609841637
# 606  tt0441773  130000000   631744560
# 621  tt0448157  150000000   624029371
# ..         ...        ...         ...
# 668  tt0811080  120000000    93945766
# 705  tt0469903   40000000     9793496
# 682  tt0970411   55000000    17869048
# 679  tt0462465   50000000     7033683
# 636  tt0455824  130000000    49554002
#
#                                         original_title  \
# 599                                    The Dark Knight
# 603  Indiana Jones and the Kingdom of the Crystal S...
# 607                                         Mamma Mia!
# 606                                      Kung Fu Panda
# 621                                            Hancock
# ..                                                 ...
# 668                                        Speed Racer
# ...

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
answers['10'] = 'The Lone Ranger (tt1210819)'
# +

# %%
imdb_1214=imdb[(imdb.release_year>=2012)&(imdb.release_year<=2014)]
imdb_1214.sort_values(['profit'])
# Out:
#         imdb_id     budget     revenue                   original_title  \
# 1245  tt1210819  255000000    89289910                  The Lone Ranger
# 1214  tt0790736  130000000    61648500                         R.I.P.D.
# 1007  tt1374992   60000000     8106475                      Upside Down
# 1302  tt0884726   70000000    18662027  Legends of Oz: Dorothy's Return
# 1235  tt1308729   55000000     9489829               Bullet to the Head
# ...         ...        ...         ...                              ...
# 1189  tt1690953   76000000   970761885                  Despicable Me 2
# 974   tt1074638  200000000  1108561013                          Skyfall
# 1180  tt1300854  200000000  1215439994                       Iron Man 3
# 1177  tt2294629  150000000  1274219009                           Frozen
# 970   tt0848228  220000000  1519557910                     The Avengers
#
#                                                    cast  \
# ...

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
answers['11'] = 'Drama'
# +

# %%
# эту задачу тоже можно решать разными подходами, попробуй реализовать разные варианты
# если будешь добавлять функцию - выноси ее в предобработку что в начале
imdb_g=imdb.copy()
imdb_g['genres']=imdb_g['genres'].str.split('|')
imdb_g=imdb_g.explode('genres')
imdb_g.genres.value_counts()
# Out:
# Drama              782
# Comedy             683
# Thriller           596
# Action             582
# Adventure          415
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            222
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             19
# Documentary          8
# Foreign              2
# Name: genres, dtype: int64

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
answers['12'] = 'Drama'
# +

# %%
imdb_g[imdb_g.profit>0].genres.value_counts()
# Out:
# Drama              560
# Comedy             551
# Thriller           446
# Action             444
# Adventure          337
# Romance            242
# Crime              231
# Family             226
# Science Fiction    195
# Fantasy            188
# Horror             150
# Animation          120
# Mystery            119
# Music               47
# History             46
# War                 41
# Western             12
# Documentary          7
# Name: genres, dtype: int64

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сборы?

# %%
answers['13'] = 'Peter Jackson'
# +

# %%
directors=imdb.groupby(['director']).sum().sort_values(['revenue'],ascending=False).head(20)
directors
# Out:
#                        budget     revenue  runtime  vote_average  \
# director
# Peter Jackson      1288000000  6490593685     1355          58.1
# Christopher Nolan  1005000000  4167548502     1135          61.1
# David Yates         775000000  4154295625      567          29.6
# Michael Bay        1126000000  3886938960     1209          50.0
# J.J. Abrams         740000000  3579169916      633          35.1
# Gore Verbinski     1155000000  3426362290     1058          51.2
# Steven Spielberg    937000000  3386700791     1356          66.9
# Ridley Scott       1220000000  3264035909     1652          78.1
# Francis Lawrence    703000000  3179979588      747          40.5
# Sam Raimi           837000000  3091066354      727          36.7
# Joss Whedon         500000000  2924593677      284          14.7
# James Cameron       250000000  2798546718      254          13.8
# Tim Burton          769000000  2493468396      888          51.4
# ...

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
answers['14'] = 'Robert Rodriguez'
# +

# %%
act=imdb[imdb.genres.str.contains('Action')].copy()
act['director']=act['director'].str.split('|')
act=act.explode('director')
act.director.value_counts()
# Out:
# Robert Rodriguez      9
# Paul W.S. Anderson    7
# Michael Bay           7
# Antoine Fuqua         6
# Ridley Scott          6
#                      ..
# Brian Helgeland       1
# Ericson Core          1
# Phil Joanou           1
# Chris Columbus        1
# Steven Brill          1
# Name: director, Length: 364, dtype: int64

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
answers['15'] = 'Chris Hemsworth'
# +

# %%
imdb_2012=imdb[imdb.release_year==2012].copy()
imdb_2012['cast']=imdb_2012['cast'].str.split('|')
imdb_2012=imdb_2012.explode('cast')
imdb_2012.groupby(['cast']).sum().sort_values(['revenue'],ascending=False)
# Out:
#                       budget     revenue  runtime  vote_average  release_year  \
# cast
# Chris Hemsworth    485000000  2027450773      458          24.8          8048
# Denis Leary        310000000  1629460639      224          12.6          4024
# Anne Hathaway      311000000  1522851057      322          14.5          4024
# Robert Downey Jr.  220000000  1519557910      143           7.3          2012
# Mark Ruffalo       220000000  1519557910      143           7.3          2012
# ...                      ...         ...      ...           ...           ...
# Michael Nyqvist     10000000     3428048      115           6.7          2012
# Danny Huston        35000000     2106557       96           5.1          2012
# Josh Lucas          35000000     2106557       96           5.1          2012
# Sami Gayle          35000000     2106557       96           5.1          2012
# Nicolas Cage        35000000     2106557       96           5.1          2012
#
# ...

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
answers['16'] = 'Matt Damon'
# +

# %%
imdb_mean=imdb[imdb.budget>imdb.budget.mean()].copy()
imdb_mean['cast']=imdb_mean['cast'].str.split('|')
imdb_mean=imdb_mean.explode('cast')
imdb_mean.groupby(['cast'])['original_title'].count().sort_values(ascending=False)
# Out:
# cast
# Matt Damon           18
# Adam Sandler         17
# Angelina Jolie       16
# Eddie Murphy         15
# Samuel L. Jackson    15
#                      ..
# Leslie Bibb           1
# Leonard Nimoy         1
# Lennie James          1
# Lena Olin             1
# 50 Cent               1
# Name: original_title, Length: 1505, dtype: int64

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
answers['17'] = 'Action'
# +

# %%
nic=imdb[imdb.cast.str.contains('Nicolas Cage')].copy()
nic['genres']=nic['genres'].str.split('|')
nic=nic.explode('genres')
nic.genres.value_counts()
# Out:
# Action             17
# Thriller           15
# Drama              12
# Crime              10
# Fantasy             8
# Adventure           7
# Comedy              6
# Science Fiction     4
# Mystery             3
# Animation           3
# Family              3
# History             2
# Romance             1
# War                 1
# Horror              1
# Name: genres, dtype: int64

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
answers['18'] = 'K-19: The Widowmaker (tt0267626)'
# +

# %%
# Вариант 1
pr=imdb[imdb.production_companies.str.contains('Paramount Pictures')].profit.min()
display(pr)
imdb[imdb.profit==-64831034]
# Out:
# -64831034
#        imdb_id     budget   revenue        original_title  \
# 925  tt0267626  100000000  35168966  K-19: The Widowmaker
#
#                                                   cast         director  \
# 925  Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...  Kathryn Bigelow
#
#                       tagline  \
# 925  Fate has found its hero.
#
#                                               overview  runtime  \
# 925  When Russia's first nuclear submarine malfunct...      138
#
#                      genres  \
# 925  Thriller|Drama|History
#
#                                   production_companies release_date  \
# 925  Paramount Pictures|Intermedia Films|National G...    7/19/2002
#
#      vote_average  release_year    profit
# 925           6.0          2002 -64831034

# %%
# Вариант 2
imdb[imdb.production_companies.str.contains('Paramount Pictures')].sort_values(['profit'])
# Out:
#         imdb_id     budget     revenue  \
# 925   tt0267626  100000000    35168966
# 1123  tt0300556   80000000    19480739
# 1722  tt0435705   70000000    18211013
# 1623  tt0375173   60000000    13395939
# 1631  tt0315297   50000000    25195000
# ...         ...        ...         ...
# 730   tt1229238  145000000   694713380
# 1738  tt0418279  150000000   709709780
# 603   tt0367882  185000000   786636033
# 317   tt1055369  150000000   836297228
# 828   tt1399103  195000000  1123746996
#
#                                          original_title  \
# 925                                K-19: The Widowmaker
# 1123                                           Timeline
# 1722                                               Next
# 1623                                              Alfie
# 1631                                            Twisted
# ...                                                 ...
# 730                Mission: Impossible - Ghost Protocol
# ...

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
answers['19'] = '2015'
# +

# %%
imdb.groupby(['release_year']).sum().sort_values(['revenue'],ascending=False)
# Out:
#                   budget      revenue  runtime  vote_average       profit
# release_year
# 2015          6780630004  25449202382    13355         755.2  18668572378
# 2014          7008050000  23405862953    13444         774.5  16397812953
# 2013          7970620000  23213799791    15039         846.9  15243179791
# 2012          7002000000  23079001687    12145         682.1  16077001687
# 2011          7946550531  22676791872    15355         868.5  14730241341
# 2010          7540000000  21071204961    13592         762.1  13531204961
# 2009          6838046652  20261791024    14187         800.2  13423744372
# 2008          6588900000  18252781990    12979         731.1  11663881990
# 2007          6596495000  18162406801    14305         809.3  11565911801
# 2004          6029250000  15663430720    12014         671.3   9634180720
# 2005          6327500000  15309425558    13387         733.5   8981925558
# ...

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
answers['20'] = '2014'
# +

# %%
imdb_w=imdb[imdb.production_companies.str.contains('Warner Bros')]
imdb_w.groupby(['release_year']).sum().sort_values(['profit'],ascending=False)
# Out:
#                   budget     revenue  runtime  vote_average      profit
# release_year
# 2014           947600000  3243064519     1576          88.9  2295464519
# 2007           982000000  3183675217     1721          95.4  2201675217
# 2008           916000000  3050595031     1366          72.0  2134595031
# 2010          1034000000  3008712985     1421          79.6  1974712985
# 2011           974000000  2845393682     1248          68.3  1871393682
# 2003           890000000  2745493377     1085          56.7  1855493377
# 2009           915500000  2737954136     1305          67.9  1822454136
# 2013           963500000  2599953400     1100          59.9  1636453400
# 2004          1100000000  2731933725     1624          78.7  1631933725
# 2005           861000000  2412980298     1193          63.0  1551980298
# 2001           923000000  2266545668     1571          83.6  1343545668
# 2012           611500000  1869520056      579          30.0  1258020056
# ...

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
answers['21'] = 'Сентябрь'
# +

# %%
imdb_month=imdb.copy()
imdb_month.release_date=imdb_month.release_date.apply(lambda x:x.split('/'))
imdb_month['month']=imdb_month.release_date.apply(lambda x:x[0])
m=imdb_month.groupby(['month']).count().sort_values(['original_title'],ascending=False)
m
# Out:
#        imdb_id  budget  revenue  original_title  cast  director  tagline  \
# month
# 9          227     227      227             227   227       227      227
# 12         190     190      190             190   190       190      190
# 10         186     186      186             186   186       186      186
# 8          161     161      161             161   161       161      161
# 3          156     156      156             156   156       156      156
# 4          149     149      149             149   149       149      149
# 6          147     147      147             147   147       147      147
# 11         146     146      146             146   146       146      146
# 7          142     142      142             142   142       142      142
# 5          140     140      140             140   140       140      140
# 2          135     135      135             135   135       135      135
# 1          110     110      110             110   110       110      110
#
# ...

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
answers['22'] = '450'
# +

# %%
# Сортировка месяцев для удобства счета. Сумма 6+7+8
m.sort_values(['month'])
# Out:
#        imdb_id  budget  revenue  original_title  cast  director  tagline  \
# month
# 1          110     110      110             110   110       110      110
# 10         186     186      186             186   186       186      186
# 11         146     146      146             146   146       146      146
# 12         190     190      190             190   190       190      190
# 2          135     135      135             135   135       135      135
# 3          156     156      156             156   156       156      156
# 4          149     149      149             149   149       149      149
# 5          140     140      140             140   140       140      140
# 6          147     147      147             147   147       147      147
# 7          142     142      142             142   142       142      142
# 8          161     161      161             161   161       161      161
# 9          227     227      227             227   227       227      227
#
# ...

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
answers['23'] = 'Peter Jackson'
# +

# %%
imdb_d=imdb.copy()
imdb_d.release_date=imdb_d.release_date.apply(lambda x:x.split('/'))
imdb_d['month']=imdb_d.release_date.apply(lambda x:x[0])
imdb_w=imdb_d[(imdb_d.month=='12')|(imdb_d.month=='1')|(imdb_d.month=='2')]
imdb_w.director=imdb_w.director.apply(lambda x:x.split('|'))
imdb_w=imdb_w.explode('director')
imdb_w.groupby(['director']).count().sort_values(['original_title'],ascending=False)
# Out:
# C:\Users\dbezu\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#                    imdb_id  budget  revenue  original_title  cast  tagline  \
# director
# Peter Jackson            7       7        7               7     7        7
# Steven Soderbergh        6       6        6               6     6        6
# Clint Eastwood           6       6        6               6     6        6
# Shawn Levy               4       4        4               4     4        4
# Adam Shankman            4       4        4               4     4        4
# ...                    ...     ...      ...             ...   ...      ...
# ...

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
answers['24'] = 'Four By Two Productions'
# +

# %%
imdb_s=imdb.copy()
imdb_s.production_companies=imdb_s.production_companies.str.split('|')
imdb_s=imdb_s.explode('production_companies')
imdb_s['length']=imdb_s.original_title.apply(lambda x:len(x))
imdb_s.groupby(['production_companies']).mean().sort_values(['length'],ascending=False)
# Out:
#                                  budget      revenue  runtime  vote_average  \
# production_companies
# Four By Two Productions      18000000.0  261572744.0     82.0           6.4
# Jim Henson Company, The      28000000.0  100654149.0     81.0           6.2
# Dos Corazones                12000000.0    9622846.0    145.0           6.8
# Polsky Films                 25000000.0   10589102.0    122.0           5.8
# Museum Canada Productions   150000000.0  413106170.0    105.0           5.9
# ...                                 ...          ...      ...           ...
# Everest Entertainment        10000000.0   21587700.0    130.0           6.9
# Berlanti Productions        150000000.0  128388320.0    111.0           5.9
# Global Entertainment Group   25100000.0   29506464.0    131.0           5.6
# XM2 Productions             110000000.0  214948780.0    133.0           6.7
# Ixtlan Productions           25100000.0   29506464.0    131.0           5.6
#
# ...

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
answers['25'] = 'Midnight Picture Show'
# +

# %%
imdb_st=imdb.copy()
imdb_st.production_companies=imdb_st.production_companies.str.split('|')
imdb_st=imdb_st.explode('production_companies')
imdb_st.overview=imdb_st.overview.str.split(' ')
imdb_st['count']=imdb_st.overview.apply(lambda x:len(x))
imdb_st.groupby(['production_companies']).mean().sort_values(['count'],ascending=False)
# Out:
#                                             budget      revenue  runtime  \
# production_companies
# Midnight Picture Show                   15000000.0    3533227.0     98.0
# Heineken Branded Entertainment         150000000.0  738599701.0    138.0
# Room 9 Entertainment                     6500000.0   24793509.0     92.0
# 98 MPH Productions                      20000000.0   75597042.0    127.0
# Brookwell-McNamara Entertainment        18000000.0   47088990.0    106.0
# ...                                            ...          ...      ...
# Henceforth                              25000000.0    4644108.0    103.0
# Our Stories Films                        6600000.0   37710610.0    112.0
# London Boulevard                        25000000.0    4644108.0    103.0
# Motion Picture Corporation of America   20000000.0    8586376.0     94.0
# Empire Pictures                         75000000.0   67631903.0    123.0
#
#                                        vote_average  release_year  \
# ...

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
answers['26'] = 'Inside Out, The Dark Knight, 12 Years a Slave'
# +

# %%
# 19 ~ 1% от общего количества фильмов в датасете
imdb.sort_values(['vote_average'],ascending=False).head(19)
# Out:
#         imdb_id     budget     revenue  \
# 599   tt0468569  185000000  1001921825
# 118   tt0816692  165000000   621752480
# 125   tt2084970   14000000   233555708
# 9     tt2096673  175000000   853708609
# 34    tt3170832    6000000    35401758
# 1183  tt0993846  100000000   392000694
# 128   tt2267998   61000000   369330363
# 1191  tt2024544   20000000   187000000
# 119   tt2015381  170000000   773312399
# 1081  tt0167260   94000000  1118888979
# 1800  tt0209144    9000000    39723096
# 370   tt1375666  160000000   825500000
# 872   tt0253474   35000000   120072577
# 138   tt2278388   30000000   174600318
# 1188  tt1798709   23000000    47351251
# 28    tt1895587   20000000    88346473
# 124   tt2245084  165000000   652105443
# 177   tt2582846   12000000   305151265
# 863   tt0167261   79000000   926287400
#
#                                      original_title  \
# 599                                 The Dark Knight
# 118                                    Interstellar
# ...

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %%
answers['27'] = 'Daniel Radcliffe & Rupert Grint'
# +

# %%
from itertools import combinations
import collections
imdb_c=imdb.copy()
imdb_c['cast']=imdb_c.cast.str.split('|')
imdb_c['cast_1'] = imdb_c['cast'].apply(lambda x: list(combinations(x,2)))
imdb_c=imdb_c.explode('cast_1')
collections.Counter(imdb_c['cast_1']).most_common(1)
# Out:
# [(('Daniel Radcliffe', 'Rupert Grint'), 8)]

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': 'Pirates of the Caribbean: On Stranger Tides (tt1298650)',
#  '2': 'Gods and Generals (tt0279111)',
#  '3': 'Winnie the Pooh (tt1449283)',
#  '4': '110',
#  '5': '107',
#  '6': 'Avatar (tt0499549)',
#  '7': 'The Lone Ranger (tt1210819)',
#  '8': '1478',
#  '9': 'The Dark Knight (tt0468569)',
#  '10': 'The Lone Ranger (tt1210819)',
#  '11': 'Drama',
#  '12': 'Drama',
#  '13': 'Peter Jackson',
#  '14': 'Robert Rodriguez',
#  '15': 'Chris Hemsworth',
#  '16': 'Matt Damon',
#  '17': 'Action',
#  '18': 'K-19: The Widowmaker (tt0267626)',
#  '19': '2015',
#  '20': '2014',
#  '21': 'Сентябрь',
#  '22': '450',
#  '23': 'Peter Jackson',
#  '25': 'Midnight Picture Show',
#  '24': 'Four By Two Productions',
#  '26': 'Inside Out, The Dark Knight, 12 Years a Slave',
#  '27': 'Daniel Radcliffe & Rupert Grint'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
# Out:
# 27
